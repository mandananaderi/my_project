# %% [markdown]
# <a href="https://colab.research.google.com/github/mandananaderi/my_project/blob/main/Rossmann_Store_Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
import os

if not os.path.ismount("/content/drive"):
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define path to input data folder
data_path = "/content/drive/MyDrive/my_kaggle_project/Rossmann_Store_Prediction/input"

# List files in the input folder
print("📂 Files in input folder:")
print(os.listdir(data_path))
# Out:
# 📂 Files in input folder:
# ['sample_submission.csv', 'test.csv', 'store.csv', 'train.csv', 'rossmann-store-sales.zip']

# %%
import pandas as pd

# Load the CSV files
train = pd.read_csv(f"{data_path}/train.csv")
test = pd.read_csv(f"{data_path}/test.csv")
store = pd.read_csv(f"{data_path}/store.csv")

print("✅ Data successfully loaded.")
# Out:
# <ipython-input-6-a4641b41358f>:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(f"{data_path}/train.csv")
# ✅ Data successfully loaded.

# %% [markdown]
# Initialization

# %% [markdown]
# # Initialization

# %%
# !pip install ydata_profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=51787262dc9b2303a888bb9c7b8f278cbf9c8d75d4137309acd58681f9207f12
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# # Read Data

# %%
# Read train

df_train = pd.read_csv(f"{data_path}/train.csv")
df_train
df_train.info()
# Out:
# <ipython-input-7-8b1a20d49a47>:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv(f"{data_path}/train.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
#Read store

df_store = pd.read_csv(f"{data_path}/store.csv")
df_store
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
# Read test

df_te = pd.read_csv(f"{data_path}/test.csv")
df_te
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
# merge two datasets with store

df_test = pd.merge(df_store, df_te, on="Store")

df = pd.merge(df_store, df_train, on="Store")
df
# Out:
#          Store StoreType Assortment  CompetitionDistance  \
# 0            1         c          a               1270.0
# 1            1         c          a               1270.0
# 2            1         c          a               1270.0
# 3            1         c          a               1270.0
# 4            1         c          a               1270.0
# ...        ...       ...        ...                  ...
# 1017204   1115         d          c               5350.0
# 1017205   1115         d          c               5350.0
# 1017206   1115         d          c               5350.0
# 1017207   1115         d          c               5350.0
# 1017208   1115         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                              9.0                    2008.0       0
# 2                              9.0                    2008.0       0
# ...

# %% [markdown]
# # EDA

# %%
# EDA

profile_report = ProfileReport(df, title="EDA of Rossmann Store Sales")
profile_report.to_file("Report of Rossmann Store Sales_1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Comparison of sales on days with and without promotions

df.groupby("Promo")["Sales"].mean()

df.groupby("Promo2")["Sales"].mean()
# Out:
# Promo2
# 0    6124.710161
# 1    5423.718218
# Name: Sales, dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
# Input and Target separation

y_train = df.Sales
X_train = df.drop('Sales', axis=1)

# %%
# Removing variables with missing values ​​greater than 20% and very low correlation with the target variable

X_train_NomissVar = X_train.drop(['CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'], axis=1)
X_train_NomissVar
# Out:
#          Store StoreType Assortment  CompetitionDistance  Promo2  DayOfWeek  \
# 0            1         c          a               1270.0       0          5
# 1            1         c          a               1270.0       0          4
# 2            1         c          a               1270.0       0          3
# 3            1         c          a               1270.0       0          2
# 4            1         c          a               1270.0       0          1
# ...        ...       ...        ...                  ...     ...        ...
# 1017204   1115         d          c               5350.0       1          6
# 1017205   1115         d          c               5350.0       1          5
# 1017206   1115         d          c               5350.0       1          4
# 1017207   1115         d          c               5350.0       1          3
# 1017208   1115         d          c               5350.0       1          2
#
# ...

# %%
# Recategorizing and Encoding StoreType and Assortment

X_train_NomissVar['StoreType'] = X_train_NomissVar['StoreType'].replace({'a': '1', 'd': '2', 'c':'3', 'b': '3'})
X_train_NomissVar['Assortment'] = X_train_NomissVar['Assortment'].replace({'a': '1', 'c': '2', 'b':'2'})


def frequency_table(variable):
    unique_elements, counts = np.unique(variable, return_counts=True)
    percentages = (counts/len(variable))* 100

    for i,j,k in zip(unique_elements, counts, percentages):
        print(f"{i}: count: {j}, percentage: {k:.2f}%")

    return



recategorize_var = ['StoreType', 'Assortment']

for var in recategorize_var:
    print(frequency_table(X_train_NomissVar[var]))
# Out:
# 1: count: 551627, percentage: 54.23%
# 2: count: 312912, percentage: 30.76%
# 3: count: 152670, percentage: 15.01%
# None
# 1: count: 537445, percentage: 52.84%
# 2: count: 479764, percentage: 47.16%
# None
